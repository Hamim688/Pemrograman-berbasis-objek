# %% [markdown]
# ### Kode UTS saya(kode salah😪) :

# %%
# Kelas induk
class AlatElektronik:
    def __init__(self, merk, model, _status_daya : False):
        self.merk = merk
        self.model = model
        self._status_daya = _status_daya

    def nyalakan(self):
        if self._status_daya == True :
            print(f"Alat Elektronik dengan merk: {self.merk} model : {self.model}, Berhasil di nyalakan")
 
    def matikan(self):
        if self._status_daya == False :
            print(f"Alat Elektronik dengan merk: {self.merk} model : {self.model}, Sedang di matikan")

    def get_info(self):
        print(f"Alat elektronik memiliki merk : {self.merk} dan model : {self.model}")

# Kelas anak 1 Televisi   
class Televisi(AlatElektronik):
    def __init__(self, merk, model, ukuran_layar, _status_daya : False):
        super().__init__(merk, model)
        self._status_daya = _status_daya
        self.ukuran_layar = ukuran_layar

    def ganti_channel(self, channel):
        if self._status_daya == True:
            print(f"Televisi dengan merk : {self.merk} di ganti chennel ke : {channel}")
        
    # Override get_info
    def get_info(self):
        print(f"Televisi memiliki merk : {self.merk}, model : {self.model}, dan ukuran layar: {self.ukuran_layar} inch")

# Kelas anak 2 Radio
class Radio(AlatElektronik):
    def __init__(self, merk, model, frekuensi, _status_daya : False):
        super().__init__(merk, model)
        self._status_daya = _status_daya
        self.frekuensi = frekuensi

    def set_frekuensi(self):
        if self._status_daya == True :
            print(f"Radio telah di set ke frekuensi: {self.frekuensi} MHz")
    
    #Override get_info
    def get_info(self):
        print(f"Radio memiliki merk: {self.merk}, model : {self.model}, dan frekuensi: {self.frekuensi}")

# --- Kode Utama --- (Waktu UTS belum ada karena kekurangan waktu)
if __name__ == "__main__":
    alat_elektronik1 = AlatElektronik("Polytron","Kipas", True)
    alat_elektronik2 = AlatElektronik("Polytron","Pompa Air") #default
    tv = Televisi("Samsung", "Oled 4K",42,True)
    radio = Radio("Sony", "90an", 95.6)

    #Memanggil method dari alat elektronik 1
    alat_elektronik1.get_info()
    alat_elektronik1.nyalakan()
    print("="*80)
    #Memanggil method dari alat elektronik 1
    alat_elektronik2.get_info()
    alat_elektronik2.nyalakan()
    alat_elektronik2.matikan()
    print("="*80)
    #Memanggil method dari Televisi
    tv.get_info()
    tv.ganti_channel(14)
    tv.nyalakan()
    print("="*80)
    #Memanggil method dari Radio
    radio.get_info()
    radio.matikan()
# Out:
# Alat elektronik memiliki merk : Polytron dan model : Kipas
# Alat Elektronik dengan merk: Polytron model : Kipas, Berhasil di nyalakan
# ...
# Alat elektronik memiliki merk : Polytron dan model : Pompa Air
# Alat Elektronik dengan merk: Polytron model : Pompa Air, Sedang di matikan
# ...
# Televisi memiliki merk : Samsung, model : Oled 4K, dan ukuran layar: 42 inch
# Televisi dengan merk : Samsung di ganti chennel ke : 14
# Alat Elektronik dengan merk: Samsung model : Oled 4K, Berhasil di nyalakan
# ...
# Radio memiliki merk: Sony, model : 90an, dan frekuensi: 95.6
# Alat Elektronik dengan merk: Sony model : 90an, Sedang di matikan

# %% [markdown]
# ### Kode Benar :

# %%
class AlatElektronik():
    def __init__(self,merk, model, status_daya = False):
        self.merk = merk
        self.model = model
        self._status_daya = status_daya

    def nyalakan(self):
        self._status_daya = True
        print(f"Alat berhasil di nyalakan")

    def matikan(self):
        self._status_daya = False
        print(f"Alat di matikan")

    def get_info(self):
        print(f"Alat dengan merk {self.merk} dan model {self.model}")

    
class Televisi(AlatElektronik):
    def __init__(self,merk, model, ukuran_layar):
        super().__init__(merk, model)
        self.ukuran_layar = ukuran_layar

    def get_info(self):
        print(f"Televisi dengan merk {self.merk}, model {self.model} dan ukuran layar {self.ukuran_layar} Inch")
   
    def ganti_chanel(self, chanel):
        if self._status_daya == True :
            print(f"Televisi berhasil di ganti ke chanel {chanel}")
        else:
            print("Televisi sedang dalam keadaaan mati")

class Radio(AlatElektronik):
    def __init__(self, merk, model, frekuensi):
        super().__init__(merk, model)
        self.frekuensi = frekuensi
    
    def get_info(self):
        print(f"Radio dengan merk {self.merk}, model {self.model}, frekuensi {self.frekuensi} MHz")

    def set_frekuensi(self, frekuensi_baru):
        if self._status_daya == True :
            print(f"Radio di set dari frekuensi {self.frekuensi} ke frekuensi {frekuensi_baru} MHz")
        else :
            print("Radio sedang dalam keadaan mati")

if __name__ == "__main__":
    tv = Televisi("Polytron", "90an", 23.8)
    tv.get_info()
    tv.ganti_chanel("Global TV")
    tv.nyalakan()
    tv.ganti_chanel("Global TV")
    tv.matikan()
    print("\n")
    rd = Radio("Panasonic", "80an", 122)
    rd.get_info()
    rd.set_frekuensi(145)
    rd.nyalakan()
    rd.set_frekuensi(145)
    rd.matikan()
# Out:
# Televisi dengan merk Polytron, model 90an dan ukuran layar 23.8 Inch
# Televisi sedang dalam keadaaan mati
# Alat berhasil di nyalakan
# Televisi berhasil di ganti ke chanel Global TV
# Alat di matikan
#
#
# Radio dengan merk Panasonic, model 80an, frekuensi 122 MHz
# Radio sedang dalam keadaan mati
# Alat berhasil di nyalakan
# Radio di set dari frekuensi 122 ke frekuensi 145 MHz
# Alat di matikan

# %% [markdown]
# # KODE SEMPUERNAAAA

# %%
class AlatElektronik:
    """
    kelas induk untuk mempresentasikan alat elektronik
    """
    def __init__(self, merk: str, model: str) :
        self.merk = merk
        self.model = model
        self._status_daya = False # Default mati

    def nyalakan(self):
        """Mengubah _status_daya menjadi True dan mencetak pesan"""
        if not self._status_daya:
            self._status_daya = True
            print(f"{self.merk} {self.model} telah dinyalakan.")
        else :
            print(f"{self.merk} {self.model} sudah dalam keadaan menyala.")

        
    def matikan(self):
        """Mengubah _status_daya menjadi False dan mencetak pesan"""
        if self._status_daya:
            self._status_daya = False
            print(f"{self.merk} {self.model} telah dimatikan.")
        else :
            print(f"{self.merk} {self.model} sudah dalam keadaan mati.")

    def get_info(self):
        """Mencetak informasi dasar (merk dan model) dan status daya"""
        print(f"--- Informasi Alat ---")
        print(f"Merk : {self.merk}")
        print(f"Model : {self.model}")
        print(f"Status daya : {'Menyala' if self._status_daya else 'Mati'}")

class Televisi(AlatElektronik):
    """
    Kelas anak unutk mempresentaikan Televisi
    """
    def __init__(self, merk : str, model : str, ukuran_layar : int):
        super().__init__(merk, model)
        self.ukuran_layar = ukuran_layar

    def get_info(self): # Override
        """Menampilkan informasi merk, model, dan ukuran layar"""
        print(f"--- Informasi Televisi ---")
        print(f"Merk : {self.merk}")
        print(f"Model : {self.model}")
        print(f"Ukuran layar : {self.ukuran_layar} inch")
        print(f"Status daya : {'Menyala' if self._status_daya else 'Mati'}")

    def ganti_channel(self, channel : int):
        """Mencetak pesan penggantian channel (hanya jika televisi menyala)"""
        if self._status_daya:
            print(f"Televisi {self.merk} {self.model}: Ganti channel ke : {channel}.")
        else:
            print(f"Televisi {self.merk} {self.model} dalam keaadaan mati. Tidak bisa ganti channel.")

class Radio(AlatElektronik):
    """
    Kelas Anak untuk mempresentasikan Radio
    """
    def __init__(self, merk : str, model : str, frekuensi: float):
        super().__init__(merk, model)
        self.frekuensi = frekuensi

    def get_info(self): # Override
        """Menampilkan informasi merk, model, dan frekuensi saat init"""
        print(f"--- Informasi Radio ---")
        print(f"Merk : {self.merk}")
        print(f"Model : {self.model}")
        print(f"Frekuensi : {self.frekuensi} MHz")
        print(f"Status daya : {'Menyala' if self._status_daya else 'Mati'}")

    def set_frekuensi(self, frekuensi_baru : float):
        """Mengubah nilai atribut frekuensi (hanya jika Radio Menyala)"""
        if self._status_daya:
            self.frekuensi = frekuensi_baru
            print(f"Radio {self.merk} {self.model}: Frekuensi di ubah ke {self.frekuensi} MHz.")
        else:
            print(f"Radio {self.merk} {self.model} dalam keaadaan mati. Tidak bisa ganti Frekuensi.")

if __name__ == "__main__":
    print("--- Demonstrasi Televisi ---")
    tv_samsung = Televisi(merk="Samsung", model="QLED Q80A", ukuran_layar=65)
    tv_samsung.get_info() # Awalnya mati
    tv_samsung.nyalakan()
    tv_samsung.get_info()
    tv_samsung.ganti_channel(channel=7)
    tv_samsung.matikan()
    tv_samsung.ganti_channel(channel=10) # Saat mati
    print("\n")

    print("--- Demonstrasi Radio ---")
    radio_sony = Radio(merk="Sony", model="ICF_P27", frekuensi=98.5)
    radio_sony.get_info() # Awalnya mati
    radio_sony.nyalakan()
    radio_sony.get_info()
    radio_sony.set_frekuensi(frekuensi_baru=101.1)
    radio_sony.matikan()
    radio_sony.set_frekuensi(frekuensi_baru=90.0) # Saat mati
# Out:
# --- Demonstrasi Televisi ---
# --- Informasi Televisi ---
# Merk : Samsung
# Model : QLED Q80A
# Ukuran layar : 65 inch
# Status daya : Mati
# Samsung QLED Q80A telah dinyalakan.
# --- Informasi Televisi ---
# Merk : Samsung
# Model : QLED Q80A
# Ukuran layar : 65 inch
# Status daya : Menyala
# Televisi Samsung QLED Q80A: Ganti channel ke : 7.
# Samsung QLED Q80A telah dimatikan.
# Televisi Samsung QLED Q80A dalam keaadaan mati. Tidak bisa ganti channel.
#
#
# --- Demonstrasi Radio ---
# --- Informasi Radio ---
# Merk : Sony
# Model : ICF_P27
# Frekuensi : 98.5 MHz
# Status daya : Mati
# Sony ICF_P27 telah dinyalakan.
# --- Informasi Radio ---
# Merk : Sony
# Model : ICF_P27
# Frekuensi : 98.5 MHz
# Status daya : Menyala
# Radio Sony ICF_P27: Frekuensi di ubah ke 101.1 MHz.
# Sony ICF_P27 telah dimatikan.
# Radio Sony ICF_P27 dalam keaadaan mati. Tidak bisa ganti Frekuensi.
